# %% [markdown]
# # News impact on stock prices

# %% [markdown]
# This example is going to show the particular case of news impact

# %%
import numpy as np

np.exp(1)+np.pi
# Out:
# 5.859874482048838

# %%
for c in range(100,1000):
    print(c)
    print(np.exp(1) * c + np.pi * c)
    residuo = (np.exp(1) * c + np.pi * c )/ (np.exp(1) + np.pi)
    print(residuo)
# Out:
# 100
# 585.9874482048838
# 100.0
# 101
# 591.8473226869327
# 101.00000000000001
# 102
# 597.7071971689816
# 102.00000000000001
# 103
# 603.5670716510303
# 103.00000000000001
# 104
# 609.4269461330791
# 104.0
# 105
# 615.286820615128
# 105.00000000000001
# 106
# 621.1466950971769
# 106.00000000000001
# 107
# 627.0065695792257
# 107.00000000000001
# 108
# 632.8664440612745
# 108.0
# 109
# 638.7263185433233
# 108.99999999999999
# 110
# 644.5861930253723
# 110.00000000000001
# 111
# 650.446067507421
# 111.00000000000001
# 112
# 656.3059419894698
# 112.0
# 113
# 662.1658164715187
# 113.00000000000001
# 114
# 668.0256909535676
# 114.00000000000001
# 115
# 673.8855654356164
# 115.00000000000001
# 116
# 679.7454399176652
# 116.0
# 117
# 685.6053143997141
# 117.00000000000001
# 118
# 691.465188881763
# 118.00000000000001
# 119
# 697.3250633638118
# 119.00000000000001
# 120
# 703.1849378458605
# 120.0
# 121
# 709.0448123279094
# 121.00000000000001
# 122
# 714.9046868099583
# 122.00000000000001
# ...

# %%
585/100
# Out:
# 5.85

# %%
1840/314
# Out:
# 5.859872611464968

# %%
334/57
# Out:
# 5.859649122807017

# %%
920/157
# Out:
# 5.859872611464968
